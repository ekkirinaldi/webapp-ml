# %%
import sys

!"{sys.executable}" -m pip install -U pandas-profiling[notebook]
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# zsh:1: no matches found: pandas-profiling[notebook]
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK

# %%
# Standard Library Imports
from pathlib import Path

# Installed packages
import pandas as pd
from ipywidgets import widgets

# Our package
from pandas_profiling import ProfileReport
from pandas_profiling.utils.cache import cache_file

# %%
# Read the Titanic Dataset
file_name = cache_file(
    "titanic.csv",
    "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv",
)
df = pd.read_csv(file_name)

# %%
# Generate the Profiling Report
profile = ProfileReport(
    df, title="Titanic Dataset", html={"style": {"full_width": True}}, sort=None, vars={"num": {"low_categorical_threshold": 0}}
)

# %%
# The Notebook Widgets Interface
profile.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# Input In [8], in <cell line: 2>()
#       1 # The Notebook Widgets Interface
# ----> 2 profile.to_widgets()
#
# File ~/miniforge3/envs/kaggle-titanic/lib/python3.10/site-packages/pandas_profiling/profile_report.py:414, in ProfileReport.to_widgets(self)
#     410     pass
#     412 from IPython.core.display import display
# --> 414 display(self.widgets)
#
# File ~/miniforge3/envs/kaggle-titanic/lib/python3.10/site-packages/pandas_profiling/profile_report.py:197, in ProfileReport.widgets(self)
#     194 @property
#     195 def widgets(self) -> Renderable:
#     196     if self._widgets is None:
# --> 197         self._widgets = self._render_widgets()
#     198     return self._widgets
#
# File ~/miniforge3/envs/kaggle-titanic/lib/python3.10/site-packages/pandas_profiling/profile_report.py:323, in ProfileReport._render_widgets(self)
#     315 report = self.report
#     317 with tqdm(
#     318     total=1,
#     319     desc="Render widgets",
#     320     disable=not self.config.progress_bar,
#     321     leave=False,
#     322 ) as pbar:
# --> 323     widgets = WidgetReport(copy.deepcopy(report)).render()
#     324     pbar.update()
#     325 return widgets
#
# File ~/miniforge3/envs/kaggle-titanic/lib/python3.10/site-packages/pandas_profiling/report/presentation/flavours/widget/root.py:9, in WidgetRoot.render(self, **kwargs)
#       7 def render(self, **kwargs) -> widgets.VBox:
#       8     return widgets.VBox(
# ----> 9         [self.content["body"].render(), self.content["footer"].render()]
#      10     )
#
# File ~/miniforge3/envs/kaggle-titanic/lib/python3.10/site-packages/pandas_profiling/report/presentation/flavours/widget/container.py:106, in WidgetContainer.render(self)
#     104     widget = get_named_list(self.content["items"])
#     105 elif self.sequence_type in ["tabs", "sections", "select"]:
# --> 106     widget = get_tabs(self.content["items"])
#     107 elif self.sequence_type == "accordion":
#     108     widget = get_accordion(self.content["items"])
#
# File ~/miniforge3/envs/kaggle-titanic/lib/python3.10/site-packages/pandas_profiling/report/presentation/flavours/widget/container.py:20, in get_tabs(items)
#      18 titles = []
#      19 for item in items:
# ---> 20     children.append(item.render())
#      21     titles.append(get_name(item))
#      23 tab = widgets.Tab()
#
# File ~/miniforge3/envs/kaggle-titanic/lib/python3.10/site-packages/pandas_profiling/report/presentation/flavours/widget/container.py:108, in WidgetContainer.render(self)
#     106     widget = get_tabs(self.content["items"])
#     107 elif self.sequence_type == "accordion":
# --> 108     widget = get_accordion(self.content["items"])
#     109 elif self.sequence_type == "grid":
#     110     widget = get_row(self.content["items"])
#
# File ~/miniforge3/envs/kaggle-titanic/lib/python3.10/site-packages/pandas_profiling/report/presentation/flavours/widget/container.py:89, in get_accordion(items)
#      87 titles = []
#      88 for item in items:
# ---> 89     children.append(item.render())
#      90     titles.append(get_name(item))
#      92 accordion = widgets.Accordion(children=children)
#
# File ~/miniforge3/envs/kaggle-titanic/lib/python3.10/site-packages/pandas_profiling/report/presentation/flavours/widget/variable.py:10, in WidgetVariable.render(self)
#       8 items = [self.content["top"].render()]
#       9 if self.content["bottom"] is not None:
# ---> 10     items.append(self.content["bottom"].render())
#      12 return widgets.VBox(items)
#
# File ~/miniforge3/envs/kaggle-titanic/lib/python3.10/site-packages/pandas_profiling/report/presentation/flavours/widget/collapse.py:14, in WidgetCollapse.render(self)
#      11     collapse = "variable"
#      13 toggle = self.content["button"].render()
# ---> 14 item = self.content["item"].render()
#      16 if collapse == "correlation":
#      18     def toggle_func(widg: dict) -> None:
#
# File ~/miniforge3/envs/kaggle-titanic/lib/python3.10/site-packages/pandas_profiling/report/presentation/flavours/widget/container.py:106, in WidgetContainer.render(self)
#     104     widget = get_named_list(self.content["items"])
#     105 elif self.sequence_type in ["tabs", "sections", "select"]:
# --> 106     widget = get_tabs(self.content["items"])
#     107 elif self.sequence_type == "accordion":
#     108     widget = get_accordion(self.content["items"])
#
# File ~/miniforge3/envs/kaggle-titanic/lib/python3.10/site-packages/pandas_profiling/report/presentation/flavours/widget/container.py:20, in get_tabs(items)
#      18 titles = []
#      19 for item in items:
# ---> 20     children.append(item.render())
#      21     titles.append(get_name(item))
#      23 tab = widgets.Tab()
#
# File ~/miniforge3/envs/kaggle-titanic/lib/python3.10/site-packages/pandas_profiling/report/presentation/flavours/widget/container.py:110, in WidgetContainer.render(self)
#     108     widget = get_accordion(self.content["items"])
#     109 elif self.sequence_type == "grid":
# --> 110     widget = get_row(self.content["items"])
#     111 elif self.sequence_type == "batch_grid":
#     112     widget = get_batch_grid(
#     113         self.content["items"],
#     114         self.content["batch_size"],
#     115         self.content.get("titles", True),
#     116         self.content.get("subtitles", False),
#     117     )
#
# File ~/miniforge3/envs/kaggle-titanic/lib/python3.10/site-packages/pandas_profiling/report/presentation/flavours/widget/container.py:57, in get_row(items)
#      54 else:
#      55     raise ValueError("Layout undefined for this number of columns")
# ---> 57 return widgets.GridBox([item.render() for item in items], layout=layout)
#
# File ~/miniforge3/envs/kaggle-titanic/lib/python3.10/site-packages/pandas_profiling/report/presentation/flavours/widget/container.py:57, in <listcomp>(.0)
#      54 else:
#      55     raise ValueError("Layout undefined for this number of columns")
# ---> 57 return widgets.GridBox([item.render() for item in items], layout=layout)
#
# File ~/miniforge3/envs/kaggle-titanic/lib/python3.10/site-packages/pandas_profiling/report/presentation/flavours/widget/container.py:106, in WidgetContainer.render(self)
#     104     widget = get_named_list(self.content["items"])
#     105 elif self.sequence_type in ["tabs", "sections", "select"]:
# --> 106     widget = get_tabs(self.content["items"])
#     107 elif self.sequence_type == "accordion":
#     108     widget = get_accordion(self.content["items"])
#
# File ~/miniforge3/envs/kaggle-titanic/lib/python3.10/site-packages/pandas_profiling/report/presentation/flavours/widget/container.py:20, in get_tabs(items)
#      18 titles = []
#      19 for item in items:
# ---> 20     children.append(item.render())
#      21     titles.append(get_name(item))
#      23 tab = widgets.Tab()
#
# File ~/miniforge3/envs/kaggle-titanic/lib/python3.10/site-packages/pandas_profiling/report/presentation/flavours/widget/container.py:104, in WidgetContainer.render(self)
#     102     widget = get_list(self.content["items"])
#     103 elif self.sequence_type == "named_list":
# --> 104     widget = get_named_list(self.content["items"])
#     105 elif self.sequence_type in ["tabs", "sections", "select"]:
#     106     widget = get_tabs(self.content["items"])
#
# File ~/miniforge3/envs/kaggle-titanic/lib/python3.10/site-packages/pandas_profiling/report/presentation/flavours/widget/container.py:36, in get_named_list(items)
#      34 def get_named_list(items: List[Renderable]) -> widgets.VBox:
#      35     return widgets.VBox(
# ---> 36         [
#      37             widgets.VBox(
#      38                 [widgets.HTML(f"<strong>{get_name(item)}</strong>"), item.render()]
#      39             )
#      40             for item in items
#      41         ]
#      42     )
#
# File ~/miniforge3/envs/kaggle-titanic/lib/python3.10/site-packages/pandas_profiling/report/presentation/flavours/widget/container.py:38, in <listcomp>(.0)
#      34 def get_named_list(items: List[Renderable]) -> widgets.VBox:
#      35     return widgets.VBox(
#      36         [
#      37             widgets.VBox(
# ---> 38                 [widgets.HTML(f"<strong>{get_name(item)}</strong>"), item.render()]
#      39             )
#      40             for item in items
#      41         ]
#      42     )
#
# File ~/miniforge3/envs/kaggle-titanic/lib/python3.10/site-packages/pandas_profiling/report/presentation/flavours/widget/frequency_table.py:56, in WidgetFrequencyTable.render(self)
#      45     else:
#      46         items.append(
#      47             (
#      48                 widgets.Label(str(row["label"])),
#    (...)
#      53             )
#      54         )
# ---> 56 return get_table(items)
#
# File ~/miniforge3/envs/kaggle-titanic/lib/python3.10/site-packages/pandas_profiling/report/presentation/flavours/widget/frequency_table.py:11, in get_table(items)
#       8 def get_table(
#       9     items: List[Tuple[widgets.Label, widgets.FloatProgress, widgets.Label]]
#      10 ) -> VBox:
# ---> 11     table = GridspecLayout(len(items), 3)
#      12     for row_id, (label, progress, count) in enumerate(items):
#      13         table[row_id, 0] = label
#
# File ~/miniforge3/envs/kaggle-titanic/lib/python3.10/site-packages/ipywidgets/widgets/widget_templates.py:282, in GridspecLayout.__init__(self, n_rows, n_columns, **kwargs)
#     280 def __init__(self, n_rows=None, n_columns=None, **kwargs):
#     281     super(GridspecLayout, self).__init__(**kwargs)
# --> 282     self.n_rows = n_rows
#     283     self.n_columns = n_columns
#     284     self._grid_template_areas = [['.'] * self.n_columns for i in range(self.n_rows)]
#
# File ~/miniforge3/envs/kaggle-titanic/lib/python3.10/site-packages/traitlets/traitlets.py:606, in TraitType.__set__(self, obj, value)
#     604     raise TraitError('The "%s" trait is read-only.' % self.name)
#     605 else:
# --> 606     self.set(obj, value)
#
# File ~/miniforge3/envs/kaggle-titanic/lib/python3.10/site-packages/traitlets/traitlets.py:580, in TraitType.set(self, obj, value)
#     579 def set(self, obj, value):
# --> 580     new_value = self._validate(obj, value)
#     581     try:
#     582         old_value = obj._trait_values[self.name]
#
# File ~/miniforge3/envs/kaggle-titanic/lib/python3.10/site-packages/traitlets/traitlets.py:614, in TraitType._validate(self, obj, value)
#     612     value = self.validate(obj, value)
#     613 if obj._cross_validation_lock is False:
# --> 614     value = self._cross_validate(obj, value)
#     615 return value
#
# File ~/miniforge3/envs/kaggle-titanic/lib/python3.10/site-packages/traitlets/traitlets.py:620, in TraitType._cross_validate(self, obj, value)
#     618 if self.name in obj._trait_validators:
#     619     proposal = Bunch({'trait': self, 'value': value, 'owner': obj})
# --> 620     value = obj._trait_validators[self.name](obj, proposal)
#     621 elif hasattr(obj, '_%s_validate' % self.name):
#     622     meth_name = '_%s_validate' % self.name
#
# File ~/miniforge3/envs/kaggle-titanic/lib/python3.10/site-packages/traitlets/traitlets.py:977, in EventHandler.__call__(self, *args, **kwargs)
#     975 """Pass `*args` and `**kwargs` to the handler's function if it exists."""
#     976 if hasattr(self, 'func'):
# --> 977     return self.func(*args, **kwargs)
#     978 else:
#     979     return self._init_call(*args, **kwargs)
#
# File ~/miniforge3/envs/kaggle-titanic/lib/python3.10/site-packages/ipywidgets/widgets/widget_templates.py:295, in GridspecLayout._validate_integer(self, proposal)
#     293 if proposal['value'] > 0:
#     294     return proposal['value']
# --> 295 raise TraitError('n_rows and n_columns must be positive integer')
#
# TraitError: n_rows and n_columns must be positive integer
